# %%
import pandas as pd
import numpy as np

# %%
#  Use ordinal encoding fro input columns and label encoding for output columns.

# %%
df = pd.read_csv('./Dataset/purchase_data.csv')

# %%
df.sample(5)
# Out:
#      Age  Gender   Review Education Purchased
# 95    18  Female  Average        PG       Yes
# 47    42    Male     Good        PG       Yes
# 126   22  Female     Good        UG       Yes
# 14    18  Female     Best        HS        No
# 136   24    Male     Good        PG       Yes

# %%
# Only taking Review, and Education as they are Oridinal Encoding

# %%
df = df.iloc[:,2:]

# %%
df
# Out:
#       Review Education Purchased
# 0       Best        UG       Yes
# 1       Good        UG       Yes
# 2       Good        UG       Yes
# 3       Best        UG       Yes
# 4       Good        UG        No
# ..       ...       ...       ...
# 195  Average        UG       Yes
# 196     Good        PG        No
# 197     Best        UG        No
# 198  Average        PG        No
# 199     Good        UG        No
#
# [200 rows x 3 columns]

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,0:2],
                                                   df.iloc[:,-1],
                                                    test_size = 0.2)

# %%
X_train.shape, X_test.shape,y_train.shape, y_test.shape
# Out:
# ((160, 2), (40, 2), (160,), (40,))

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
Obj = OrdinalEncoder(categories = [['Average', 'Good', 'Best'], ['HS', 'UG', 'PG']])

# %%
Obj.fit(X_train)
# Out:
# OrdinalEncoder(categories=[['Average', 'Good', 'Best'], ['HS', 'UG', 'PG']])

# %%
X_train_encoded = Obj.transform(X_train)
X_test_encoded = Obj.transform(X_test)

# %%
X_train_encoded
# Out:
# array([[0., 0.],
#        [2., 2.],
#        [0., 1.],
#        [1., 2.],
#        [2., 2.],
#        [1., 1.],
#        [1., 1.],
#        [2., 0.],
#        [0., 2.],
#        [1., 1.],
#        [2., 1.],
#        [1., 1.],
#        [2., 2.],
#        [1., 1.],
#        [2., 0.],
#        [2., 2.],
#        [1., 1.],
#        [2., 0.],
#        [1., 1.],
#        [2., 1.],
#        [2., 0.],
#        [1., 2.],
#        [1., 0.],
#        [1., 0.],
#        [2., 1.],
#        [2., 1.],
#        [0., 1.],
#        [1., 0.],
#        [1., 2.],
#        [2., 0.],
#        [2., 0.],
#        [0., 1.],
#        [0., 0.],
#        [2., 1.],
#        [0., 2.],
#        [0., 1.],
#        [0., 2.],
#        [1., 0.],
#        [0., 0.],
#        [1., 2.],
#        [0., 2.],
#        [1., 1.],
#        [1., 1.],
#        [1., 2.],
#        [0., 1.],
#        [1., 1.],
#        [0., 2.],
#        [2., 2.],
#        [0., 2.],
#        [2., 1.],
#        [0., 1.],
#        [0., 2.],
# ...

# %%
Obj.categories
# Out:
# [['Average', 'Good', 'Best'], ['HS', 'UG', 'PG']]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
le.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
le.fit(y_train)
# Out:
# LabelEncoder()

# %%
y_train_le = le.transform(y_train)
y_test_le = le.transform(y_test)

# %%
y_train = pd.DataFrame(y_train)

# %%
y_train
# Out:
#     Purchased
# 107        No
# 24        Yes
# 32        Yes
# 91        Yes
# 117       Yes
# ..        ...
# 31         No
# 51         No
# 146       Yes
# 25         No
# 46        Yes
#
# [160 rows x 1 columns]
